# %% [markdown]
# <a href="https://colab.research.google.com/github/ttt1088/2d-extras/blob/master/layerdivider_launch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Please set runtime to GPU

# %%
# !git clone https://github.com/mattyamonaca/layerdivider.git
# %cd layerdivider
# !sed -i 's/==.*//g' requirements.txt   # <--- 请务必加上这行！它的作用是自动删掉所有 == 和后面的数字
# !pip install -r requirements.txt
# Out:
# Cloning into 'layerdivider'...
# remote: Enumerating objects: 439, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 439 (delta 127), reused 116 (delta 96), pack-reused 277 (from 1)
# Receiving objects: 100% (439/439), 28.47 MiB | 26.24 MiB/s, done.
# Resolving deltas: 100% (255/255), done.

# %%
# %cd layerdivider
# Out:
# /content/layerdivider/layerdivider

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
#   Using cached pandas-1.5.3.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !python demo.py share
# Out:
# Traceback (most recent call last):
#   File "/content/layerdivider/layerdivider/demo.py", line 6, in <module>
#     from ldivider.ld_processor import get_base, get_normal_layer, get_composite_layer, get_seg_base
#   File "/content/layerdivider/layerdivider/ldivider/ld_processor.py", line 9, in <module>
#     from ldivider.ld_utils import img_plot
#   File "/content/layerdivider/layerdivider/ldivider/ld_utils.py", line 6, in <module>
#     from pytoshop import layers
# ModuleNotFoundError: No module named 'pytoshop'
